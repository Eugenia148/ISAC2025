# %%
import os
from dotenv import load_dotenv
from statsbombpy import sb
import pandas as pd
# Load environment variables from .env file (if it exists)
load_dotenv()

# Set credentials if available
username = os.getenv('SB_USERNAME')
password = os.getenv('SB_PASSWORD')

if username and password:
    print("Credentials loaded successfully")
else:
    print("No credentials found - using open data access only")
# Out:
# Credentials loaded successfully

# %%
sb.competitions()
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              73        317       Mexico          Liga MX               male
# 1              73        281       Mexico          Liga MX               male
# 2              73        235       Mexico          Liga MX               male
# 3              73        108       Mexico          Liga MX               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False   2024/2025
# 1              False                      False   2023/2024
# 2              False                      False   2022/2023
# 3              False                      False   2021/2022
#
#                 match_updated           match_updated_360  \
# 0  2025-08-30T16:14:20.970616  2025-08-30T16:14:20.970616
# 1  2024-12-20T23:40:31.103974  2024-12-20T23:40:31.103974
# 2  2024-09-28T11:05:11.667984  2024-09-28T11:05:11.667984
# ...

# %%
matches_24_25 = sb.matches(competition_id=73, season_id=317)

matches_24_25.to_parquet("../data/raw/ligamx/season_317_24_25/matches.parquet")

# %%
matches_23_24 = sb.matches(competition_id=73, season_id=281)
matches_23_24.to_parquet("../data/raw/ligamx/season_281_23_24/matches.parquet")

matches_22_23 = sb.matches(competition_id=73, season_id=235)
matches_22_23.to_parquet("../data/raw/ligamx/season_235_22_23/matches.parquet")

matches_21_22 = sb.matches(competition_id=73, season_id=108)
matches_21_22.to_parquet("../data/raw/ligamx/season_108_21_22/matches.parquet")

# %%
events_24_25 = sb.competition_events(
    country="Mexico",
    gender="male",
    division= "Liga MX",
    season= "2024/2025"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 events_24_25 = sb.competition_events(
#       2     country="Mexico",
#       3     gender="male",
#       4     division= "Liga MX",
#       5     season= "2024/2025"
#       6 )
#       8 events_24_25.info()
#
# File c:\Users\carls\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\sb.py:147, in competition_events(country, division, season, gender, split, filters, fmt, creds, include_360_metrics)
#     140 events_call = partial(
#     141     events,
#     142     fmt="json",
#     143     creds=creds,
#     144     include_360_metrics=include_360_metrics,
#     145 )
#     146 with Pool(MAX_CONCURRENCY) as p:
# --> 147     matches_events = p.map(
#     148         events_call,
#     149         matches(c["competition_id"], c["season_id"], fmt="dict", creds=creds),
# ...

# %%
events_24_25.to_parquet("../data/raw/ligamx/season_317_24_25/events.parquet")

# %%
events_23_24 = sb.competition_events(
    country="Mexico",
    gender="male",
    division= "Liga MX",
    season= "2023/2024"
)
# Out:
# c:\Users\carls\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\sb.py:160: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   competition_events = pd.concat(

# %%
events_23_24.to_parquet("../data/raw/ligamx/season_281_23_24/events.parquet")

# %%
events_22_23 = sb.competition_events(
    country="Mexico",
    gender="male",
    division= "Liga MX",
    season= "2022/2023"
)
events_22_23.to_parquet("../data/raw/ligamx/season_235_22_23/events.parquet")
# Out:
# c:\Users\carls\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\sb.py:160: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   competition_events = pd.concat(

# %%
events_21_22 = sb.competition_events(
    country="Mexico",
    gender="male",
    division= "Liga MX",
    season= "2021/2022"
)
events_21_22.to_parquet("../data/raw/ligamx/season_108_21_22/events.parquet")
# Out:
# c:\Users\carls\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsbombpy\sb.py:160: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   competition_events = pd.concat(

# %%
events_21_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029393 entries, 0 to 1029392
# Columns: 135 entries, 50_50 to under_pressure
# dtypes: float64(24), int64(8), object(103)
# memory usage: 1.0+ GB

# %%
team_season_stats = sb.team_season_stats(competition_id=73, season_id=317)

team_season_stats.head()
# Out:
#    account_id    team_name  team_id  competition_id competition_name  \
# 0       41100      América     1229              73          Liga MX
# 1       41100        Atlas     1296              73          Liga MX
# 2       41100    Cruz Azul     1224              73          Liga MX
# 3       41100  Guadalajara     1297              73          Liga MX
# 4       41100         León     1302              73          Liga MX
#
#    season_id season_name  team_female  team_season_matches  \
# 0        317   2024/2025        False                   47
# 1        317   2024/2025        False                   36
# 2        317   2024/2025        False                   42
# 3        317   2024/2025        False                   35
# 4        317   2024/2025        False                   36
#
#   team_season_minutes  ...  team_season_obv_shot_conceded_pg  \
# 0                None  ...                         -0.165049
# 1                None  ...                         -0.083851
# ...

# %%
americas_24_25 = team_season_stats[team_season_stats['team_name'] == 'América']
americas_24_25

americas_24_25.columns
# Out:
# Index(['account_id', 'team_name', 'team_id', 'competition_id',
#        'competition_name', 'season_id', 'season_name', 'team_female',
#        'team_season_matches', 'team_season_minutes',
#        ...
#        'team_season_obv_shot_conceded_pg',
#        'team_season_obv_defensive_action_conceded_pg',
#        'team_season_obv_dribble_carry_conceded_pg',
#        'team_season_obv_gk_conceded_pg', 'team_season_passes_pg',
#        'team_season_successful_passes_pg', 'team_season_passes_conceded_pg',
#        'team_season_successful_passes_conceded_pg', 'team_season_op_passes_pg',
#        'team_season_op_passes_conceded_pg'],
#       dtype='object', length=181)

# %%
# sb.player_season_stats(competition_id=73, season_id=317)[['player_name', 'player_season_assists_90']]
# Out:
#                          player_name  player_season_assists_90
# 0                      Alexis Méndez                  0.000000
# 1         Fernando David Arce Juárez                  0.000000
# 2                  Cade Dylan Cowell                  0.128711
# 3     Sergio Armando Aguayo Castillo                  0.000000
# 4           Ventura Alvarado Aispuro                  0.000000
# ..                               ...                       ...
# 631              Sergio Ramos García                  0.000000
# 632                 Pau López Sabata                  0.000000
# 633           Sergio Canales Madrazo                  0.286785
# 634  Francisco José Villalba Rodrigo                  0.126767
# 635              Óliver Torres Muñoz                  0.069206
#
# [636 rows x 2 columns]

# %%
matches_24_25 = pd.read_parquet("../data/raw/ligamx/season_317_24_25/matches.parquet")
matches_24_25.head()
# Out:
#    match_id  match_date      kick_off       competition     season  \
# 0   3939828  2024-07-13  03:05:00.000  Mexico - Liga MX  2024/2025
# 1   3939831  2024-07-14  01:10:00.000  Mexico - Liga MX  2024/2025
# 2   3939858  2024-08-25  01:00:00.000  Mexico - Liga MX  2024/2025
# 3   3939953  2024-11-06  03:05:00.000  Mexico - Liga MX  2024/2025
# 4   3939874  2024-09-14  03:00:00.000  Mexico - Liga MX  2024/2025
#
#      home_team    away_team  home_score  away_score attendance  ...  \
# 0        Atlas  Tigres UANL           1           1       None  ...
# 1       Toluca       Juárez           3           2       None  ...
# 2  Tigres UANL  Guadalajara           1           1       None  ...
# 3   Pumas UNAM    Querétaro           2           0       None  ...
# 4       Necaxa   Pumas UNAM           2           0       None  ...
#
#              last_updated_360  match_week competition_stage  \
# 0  2024-07-28T14:19:51.119184           2          Apertura
# ...

# %%
sb.player_match_stats(3939874)
# Out:
#     account_id  match_id  team_id   team_name  player_id  \
# 0        41100   3939874     1301  Pumas UNAM      11500
# 1        41100   3939874     1221      Necaxa      27762
# 2        41100   3939874     1301  Pumas UNAM      23263
# 3        41100   3939874     1301  Pumas UNAM      26318
# 4        41100   3939874     1221      Necaxa      28529
# 5        41100   3939874     1301  Pumas UNAM      27897
# 6        41100   3939874     1301  Pumas UNAM      75305
# 7        41100   3939874     1301  Pumas UNAM       6612
# 8        41100   3939874     1221      Necaxa      27902
# 9        41100   3939874     1221      Necaxa      28480
# 10       41100   3939874     1221      Necaxa      32022
# 11       41100   3939874     1301  Pumas UNAM      27889
# 12       41100   3939874     1221      Necaxa      37877
# 13       41100   3939874     1301  Pumas UNAM     136926
# 14       41100   3939874     1221      Necaxa      28815
# ...

# %%
from sklearn.decomposition import PCA
americas_24_25
# Out:
#    account_id team_name  team_id  competition_id competition_name  season_id  \
# 0       41100   América     1229              73          Liga MX        317
#
#   season_name  team_female  team_season_matches team_season_minutes  ...  \
# 0   2024/2025        False                   47                None  ...
#
#    team_season_obv_shot_conceded_pg  \
# 0                         -0.165049
#
#    team_season_obv_defensive_action_conceded_pg  \
# 0                                      0.342086
#
#    team_season_obv_dribble_carry_conceded_pg  team_season_obv_gk_conceded_pg  \
# 0                                   0.580708                       -0.115983
#
#    team_season_passes_pg  team_season_successful_passes_pg  \
# 0             507.191489                        428.106383
#
#    team_season_passes_conceded_pg  team_season_successful_passes_conceded_pg  \
# 0                      434.765957                                 350.234043
#
# ...

# %%
lineup = sb.lineups(3939874)
lineup['positions']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 lineup = sb.lineups(3939874)
# ----> 2 lineup['positions']
#
# KeyError: 'positions'
